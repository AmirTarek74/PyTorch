# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %%
def preprocessing(df,le):
    df.drop(['Id'],axis=1,inplace=True)
    cols = list(df.columns)
    for col in cols:
        if df[col].dtype == 'object':
            df[col] = le.fit_transform(df[col])
    return df

# %%
le = LabelEncoder()
df1 = preprocessing(df_train,le)
df2 = preprocessing(df_test,le)

# %%
cols = df1.columns

# %%
droped = cols[df1.isnull().sum()!=0]

# %%
df1
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0             60         3         65.0     8450       1      2         3
# 1             20         3         80.0     9600       1      2         3
# 2             60         3         68.0    11250       1      2         0
# 3             70         3         60.0     9550       1      2         0
# 4             60         3         84.0    14260       1      2         0
# ...          ...       ...          ...      ...     ...    ...       ...
# 1455          60         3         62.0     7917       1      2         3
# 1456          20         3         85.0    13175       1      2         3
# 1457          70         3         66.0     9042       1      2         3
# 1458          20         3         68.0     9717       1      2         3
# 1459          20         3         75.0     9937       1      2         3
#
#       LandContour  Utilities  LotConfig  ...  PoolArea  PoolQC  Fence  \
# 0               3          0          4  ...         0       3      4
# 1               3          0          2  ...         0       3      4
# 2               3          0          4  ...         0       3      4
# 3               3          0          0  ...         0       3      4
# 4               3          0          2  ...         0       3      4
# ...           ...        ...        ...  ...       ...     ...    ...
# 1455            3          0          4  ...         0       3      4
# 1456            3          0          4  ...         0       3      2
# 1457            3          0          4  ...         0       3      0
# 1458            3          0          4  ...         0       3      4
# 1459            3          0          4  ...         0       3      4
#
#       MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0               4        0       2    2008         8              4     208500
# 1               4        0       5    2007         8              4     181500
# 2               4        0       9    2008         8              4     223500
# 3               4        0       2    2006         8              0     140000
# 4               4        0      12    2008         8              4     250000
# ...           ...      ...     ...     ...       ...            ...        ...
# 1455            4        0       8    2007         8              4     175000
# 1456            4        0       2    2010         8              4     210000
# 1457            2     2500       5    2010         8              4     266500
# 1458            4        0       4    2010         8              4     142125
# 1459            4        0       6    2008         8              4     147500
#
# [1460 rows x 80 columns]

# %%
df1.dropna(axis=0).isnul
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0             60         3         65.0     8450       1      2         3
# 1             20         3         80.0     9600       1      2         3
# 2             60         3         68.0    11250       1      2         0
# 3             70         3         60.0     9550       1      2         0
# 4             60         3         84.0    14260       1      2         0
# ...          ...       ...          ...      ...     ...    ...       ...
# 1455          60         3         62.0     7917       1      2         3
# 1456          20         3         85.0    13175       1      2         3
# 1457          70         3         66.0     9042       1      2         3
# 1458          20         3         68.0     9717       1      2         3
# 1459          20         3         75.0     9937       1      2         3
#
#       LandContour  Utilities  LotConfig  ...  PoolArea  PoolQC  Fence  \
# 0               3          0          4  ...         0       3      4
# 1               3          0          2  ...         0       3      4
# 2               3          0          4  ...         0       3      4
# 3               3          0          0  ...         0       3      4
# 4               3          0          2  ...         0       3      4
# ...           ...        ...        ...  ...       ...     ...    ...
# 1455            3          0          4  ...         0       3      4
# 1456            3          0          4  ...         0       3      2
# 1457            3          0          4  ...         0       3      0
# 1458            3          0          4  ...         0       3      4
# 1459            3          0          4  ...         0       3      4
#
#       MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0               4        0       2    2008         8              4     208500
# 1               4        0       5    2007         8              4     181500
# 2               4        0       9    2008         8              4     223500
# 3               4        0       2    2006         8              0     140000
# 4               4        0      12    2008         8              4     250000
# ...           ...      ...     ...     ...       ...            ...        ...
# 1455            4        0       8    2007         8              4     175000
# 1456            4        0       2    2010         8              4     210000
# 1457            2     2500       5    2010         8              4     266500
# 1458            4        0       4    2010         8              4     142125
# 1459            4        0       6    2008         8              4     147500
#
# [1121 rows x 80 columns]

# %%
df1.to_csv('FinalTrain.csv')
